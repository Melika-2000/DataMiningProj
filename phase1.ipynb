# %%
import pandas as pd
from IPython.display import display


INOUT = pd.read_csv('DataSets/INOUT.csv')

INOUTLINE = pd.read_csv('DataSets/INOUTLINE.csv')

PRODUCTINSTANCE = pd.read_csv('DataSets/PRODUCTINSTANCE.csv',encoding='cp1252')

PRODUCTS = pd.read_csv('DataSets/PRODUCTS.csv')

TRANSFER_ITEM = pd.read_csv('DataSets/TRANSFER_ITEM.csv')

TRANSFER_ITEM_D = pd.read_csv('DataSets/TRANSFER_ITEM_D.csv')

csvFiles = [INOUT,INOUTLINE,PRODUCTINSTANCE,PRODUCTS,TRANSFER_ITEM,TRANSFER_ITEM_D]

# %%
for file in csvFiles:
    df = pd.DataFrame()
    for attribute in file.columns:
        df.append(file[attribute].describe())
# Out:
# C:\Users\siedt\AppData\Local\Temp\ipykernel_15640\3442885146.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(file[attribute].describe())
# C:\Users\siedt\AppData\Local\Temp\ipykernel_15640\3442885146.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(file[attribute].describe())
# C:\Users\siedt\AppData\Local\Temp\ipykernel_15640\3442885146.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(file[attribute].describe())
# C:\Users\siedt\AppData\Local\Temp\ipykernel_15640\3442885146.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(file[attribute].describe())
# ...
